# %% [markdown]
# # Générateur d'une variable aléatoire uniforme sur [0,1]
#
# - Hypothèse $H_0$ : le générateur est uniforme
# - Hypothèse $H_1$ : le générateur n'est pas uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chisquare

# %%
# Définition du nombre de valeurs et du nimbre d'intervalles
N = 1000
r = 15

# %%
# Réalisations de variables suivant la loi uniforme sur [0,1]
x = np.random.uniform(0, 1, N)

# %%
# Afficher les 10 premières valeurs
x[:10]
# Out:
# array([0.76704417, 0.90317168, 0.05693521, 0.68471024, 0.47108394,
#        0.52114899, 0.63298508, 0.26793696, 0.15374705, 0.73008645])

# %%
# Affichage des réalisations
plt.scatter(np.arange(len(x)), x)

# %%
# Histogramme sur 10 intervalles
plt.hist(x, bins=r)
plt.show()

# %%
# Calcul de K_n
K_n = sum((np.histogram(x, bins=r)[0] - N/r)**2 / (N/r))
K_n
# Out:
# 5.119999999999999

# %%
# Calcul de K_n
chisquare(
    f_obs=np.histogram(x, bins=r)[0],
    f_exp=N/r,
    ddof=r-1, 
)
# Out:
# Power_divergenceResult(statistic=5.119999999999999, pvalue=nan)

# %% [markdown]
# $\chi^2_{14, 0.9}$ = 21.06
#
# Conclusion : on ne rejette pas l'hypothèse $H_0$ au quantile d'ordre $1 - \alpha$
